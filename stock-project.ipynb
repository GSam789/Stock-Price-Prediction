# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ticker_symbol = 'TSLA'
# stock_data = yf.Ticker(ticker_symbol)

stock_data = yf.download("TSLA JPM", start="2018-10-01", end="2023-10-01")
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# historical_data = stock_data.history(period="5yr")
print(stock_data)
stock_data.to_csv('stock_data.csv')
# Out:
#              Adj Close                   Close                    High  \
#                    JPM        TSLA         JPM        TSLA         JPM
# Date
# 2018-10-01   96.849579   20.713333  113.500000   20.713333  114.610001
# 2018-10-02   97.250626   20.068001  113.970001   20.068001  114.120003
# 2018-10-03   98.163651   19.653334  115.040001   19.653334  115.660004
# 2018-10-04   99.048691   18.788668  115.269997   18.788668  116.809998
# 2018-10-05   98.490166   17.463333  114.620003   17.463333  116.099998
# ...                ...         ...         ...         ...         ...
# 2023-09-25  145.377289  246.990005  146.449997  246.990005  146.520004
# 2023-09-26  143.868423  244.119995  144.929993  244.119995  145.839996
# 2023-09-27  144.712189  240.500000  145.779999  240.500000  146.089996
# 2023-09-28  146.508942  246.380005  147.589996  246.380005  148.869995
# 2023-09-29  143.957764  250.220001  145.020004  250.220001  148.759995
#
# ...

# %%
sorted_data = stock_data.sort_values(by="Date", ascending=False)
stock_data['Close'].plot(title=f"Stock Price")
plt.show()
